# %%
import pandas as pd
import json
import requests
import dotenv

# %%
url = "https://api.makcorps.com/auth"
header = {'Content-Type':'application/json'}
obj = {"username":"ryanderson94","password":"Mother_fucker1"}

# %%
request = requests.post(url=url, json = obj, headers=header)

# %%
response = json.loads(request.text)
access_token = response['access_token']
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE2NjA1MTIzNjAsImlhdCI6MTY2MDUxMDU2MCwibmJmIjoxNjYwNTEwNTYwLCJpZGVudGl0eSI6MTQ5MX0.TfMdLJhBESJg1nFOb8bunxX9Iobbq1l74TPHnj4Vu3o'

# %%
authorization_key = 'JWT ' + access_token

# %%
booking_header = {}

# %%
booking_header['Authorization'] = authorization_key
booking_header
# Out:
# {'Authorization': 'JWT eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE2NjA1MTIzNjAsImlhdCI6MTY2MDUxMDU2MCwibmJmIjoxNjYwNTEwNTYwLCJpZGVudGl0eSI6MTQ5MX0.TfMdLJhBESJg1nFOb8bunxX9Iobbq1l74TPHnj4Vu3o'}

# %%
booking_url = "https://api.makcorps.com/free/"
city = 'london'
concatenated_url = booking_url + city

# %%
concatenated_url
# Out:
# 'https://api.makcorps.com/free/london'

# %%
booking_request = requests.get(url = concatenated_url, headers=booking_header)

# %%
print(booking_request.text)
# Out:
# {
#     "Comparison": [
#         [
#             {
#                 "hotelName": "The Resident Covent Garden"
#             },
#             [
#                 {
#                     "price1": "416",
#                     "tax1": "83",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "417",
#                     "tax2": "83",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "500",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Hotel "
#             },
#             [
#                 {
#                     "price1": "470",
#                     "tax1": "94",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "470",
#                     "tax2": "94",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "565",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Shangri-La The Shard, London"
#             },
#             [
#                 {
#                     "price1": "772",
#                     "tax1": "155",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "774",
#                     "tax2": "155",
#                     "vendor2": "Expedia.it"
#                 },
#                 {
#                     "price3": "926",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Milestone Hotel and Residences"
#             },
#             [
#                 {
#                     "price1": null,
#                     "tax1": null,
#                     "vendor1": "The Milestone"
#                 },
#                 {
#                     "price2": "441",
#                     "tax2": "88",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "441",
#                     "tax3": "88",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Pan Pacific London"
#             },
#             [
#                 {
#                     "price1": "365",
#                     "tax1": "73",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "365",
#                     "tax2": "73",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": null,
#                     "tax3": null,
#                     "vendor3": null
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Claridge's"
#             },
#             [
#                 {
#                     "price1": "939",
#                     "tax1": "188",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "941",
#                     "tax2": "188",
#                     "vendor2": "Expedia.it"
#                 },
#                 {
#                     "price3": "1129",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Egerton House Hotel"
#             },
#             [
#                 {
#                     "price1": "419",
#                     "tax1": "84",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "362",
#                     "tax2": "72",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "420",
#                     "tax3": "84",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Hari"
#             },
#             [
#                 {
#                     "price1": "448",
#                     "tax1": "90",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "438",
#                     "tax2": "88",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "448",
#                     "tax3": "90",
#                     "vendor3": "eDreams"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montague on The Gardens"
#             },
#             [
#                 {
#                     "price1": "264",
#                     "tax1": "53",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "318",
#                     "tax2": "0",
#                     "vendor2": "Lol.travel"
#                 },
#                 {
#                     "price3": null,
#                     "tax3": null,
#                     "vendor3": null
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Hotel Cafe Royal"
#             },
#             [
#                 {
#                     "price1": "944",
#                     "tax1": "189",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "946",
#                     "tax2": "189",
#                     "vendor2": "Expedia.it"
#                 },
#                 {
#                     "price3": "1135",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Royal Lancaster London"
#             },
#             [
#                 {
#                     "price1": "314",
#                     "tax1": "67",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "373",
#                     "tax2": "75",
#                     "vendor2": "Destinia.com"
#                 },
#                 {
#                     "price3": null,
#                     "tax3": null,
#                     "vendor3": null
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "One Aldwych"
#             },
#             [
#                 {
#                     "price1": "858",
#                     "tax1": "172",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "698",
#                     "tax2": "140",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "860",
#                     "tax3": "172",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Victoria"
#             },
#             [
#                 {
#                     "price1": null,
#                     "tax1": null,
#                     "vendor1": "Hotels.com"
#                 },
#                 {
#                     "price2": "183",
#                     "tax2": "37",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "183",
#                     "tax3": "37",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": "220",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Bankside Hotel"
#             },
#             [
#                 {
#                     "price1": "308",
#                     "tax1": "62",
#                     "vendor1": "Autograph"
#                 },
#                 {
#                     "price2": "308",
#                     "tax2": "62",
#                     "vendor2": "Booking.com"
#                 },
#                 {
#                     "price3": "274",
#                     "tax3": "55",
#                     "vendor3": "Etrip"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Brown's Hotel"
#             },
#             [
#                 {
#                     "price1": "884",
#                     "tax1": "177",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "822",
#                     "tax2": "164",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "724",
#                     "tax3": "144",
#                     "vendor3": "FindHotel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Chesterfield Mayfair"
#             },
#             [
#                 {
#                     "price1": "495",
#                     "tax1": "99",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "473",
#                     "tax2": "95",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "496",
#                     "tax3": "99",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Holmes Hotel London"
#             },
#             [
#                 {
#                     "price1": "272",
#                     "tax1": "54",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "272",
#                     "tax2": "54",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "337",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montcalm Royal London House"
#             },
#             [
#                 {
#                     "price1": "207",
#                     "tax1": "44",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "220",
#                     "tax2": "44",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "218",
#                     "tax3": "44",
#                     "vendor3": "Destinia.com"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Connaught"
#             },
#             [
#                 {
#                     "price1": "879",
#                     "tax1": "176",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "848",
#                     "tax2": "170",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "880",
#                     "tax3": "176",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Soho"
#             },
#             [
#                 {
#                     "price1": "303",
#                     "tax1": "61",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "259",
#                     "tax2": "51",
#                     "vendor2": "FindHotel"
#                 },
#                 {
#                     "price3": "277",
#                     "tax3": "55",
#                     "vendor3": "Agoda.com"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Kensington"
#             },
#             [
#                 {
#                     "price1": "451",
#                     "tax1": "90",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "393",
#                     "tax2": "79",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "535",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Wilde Aparthotels by Staycity - Aldgate Tower Bridge"
#             },
#             [
#                 {
#                     "price1": null,
#                     "tax1": null,
#                     "vendor1": "Hotels.com"
#                 },
#                 {
#                     "price2": "186",
#                     "tax2": "37",
#                     "vendor2": "Booking.com"
#                 },
#                 {
#                     "price3": "170",
#                     "tax3": "34",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": "187",
#                     "tax4": "37",
#                     "vendor4": "Destinia.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Bloomsbury"
#             },
#             [
#                 {
#                     "price1": "356",
#                     "tax1": "71",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "353",
#                     "tax2": "71",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "428",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montcalm London Marble Arch"
#             },
#             [
#                 {
#                     "price1": "240",
#                     "tax1": "51",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "200",
#                     "tax2": "40",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "262",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Vintry & Mercer"
#             },
#             [
#                 {
#                     "price1": "230",
#                     "tax1": "46",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "230",
#                     "tax2": "46",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "296",
#                     "tax3": "59",
#                     "vendor3": "Official Site"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Beaumont"
#             },
#             [
#                 {
#                     "price1": "713",
#                     "tax1": "143",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "714",
#                     "tax2": "143",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "857",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Batty Langley's"
#             },
#             [
#                 {
#                     "price1": "251",
#                     "tax1": "50",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "252",
#                     "tax2": "50",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "302",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Taj  Buckingham Gates Suites and Residences"
#             },
#             [
#                 {
#                     "price1": "545",
#                     "tax1": "109",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "467",
#                     "tax2": "93",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "655",
#                     "tax3": "0",
#                     "vendor3": "Lol.travel"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Kensington"
#             },
#             [
#                 {
#                     "price1": "201",
#                     "tax1": "40",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "201",
#                     "tax2": "40",
#                     "vendor2": "Expedia.it"
#                 },
#                 {
#                     "price3": "201",
#                     "tax3": "40",
#                     "vendor3": "eDreams"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Stafford London"
#             },
#             [
#                 {
#                     "price1": "463",
#                     "tax1": "93",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "464",
#                     "tax2": "93",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "464",
#                     "tax3": "93",
#                     "vendor3": "Preferred Hotels"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         {
#             "totalHotelsCount": "4,236",
#             "currentPageHotelsCount": 30,
#             "totalpageCount": "142"
#         }
#     ]
# }

# %%
data = booking_request.json()
data = data['Comparison']
last_hotel = data[-2][0]['hotelName']

# %%
hotel_list = []
hotel_prices = {}
hotel_values = {}
i = 0
n = 0
k = 1

# %%
while data[i][0]['hotelName'] != last_hotel:
    hotel_list.append(data[i][0]['hotelName'])
    
    while k < 6:
        if type(data[i][1][n][f'price{k}']) == str:
            hotel_prices[f'Vendor {k}'] = data[i][1][n][f'vendor{k}']
            hotel_prices[f'Price {k}'] = float(data[i][1][n][f'price{k}']) + float(data[i][1][n][f'tax{k}'])
        k += 1
        n += 1
    
    hotel_values[data[i][0]['hotelName']] = hotel_prices
    hotel_prices = {}
    i += 1
    k = 1
    n = 0

# %%
hotel_values
# Out:
# {'The Resident Covent Garden': {'Vendor 1': 'Booking.com',
#   'Price 1': 499.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 500.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 500.0},
#  'Hotel ': {'Vendor 1': 'Booking.com',
#   'Price 1': 564.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 564.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 565.0},
#  'Shangri-La The Shard, London': {'Vendor 1': 'Booking.com',
#   'Price 1': 927.0,
#   'Vendor 2': 'Expedia.it',
#   'Price 2': 929.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 926.0},
#  'The Milestone Hotel and Residences': {'Vendor 2': 'Agoda.com',
#   'Price 2': 529.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 529.0},
#  'Pan Pacific London': {'Vendor 1': 'Booking.com',
#   'Price 1': 438.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 438.0},
#  "Claridge's": {'Vendor 1': 'Booking.com',
#   'Price 1': 1127.0,
#   'Vendor 2': 'Expedia.it',
#   'Price 2': 1129.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 1129.0},
#  'The Egerton House Hotel': {'Vendor 1': 'Booking.com',
#   'Price 1': 503.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 434.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 504.0},
#  'The Hari': {'Vendor 1': 'Booking.com',
#   'Price 1': 538.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 526.0,
#   'Vendor 3': 'eDreams',
#   'Price 3': 538.0},
#  'The Montague on The Gardens': {'Vendor 1': 'Booking.com',
#   'Price 1': 317.0,
#   'Vendor 2': 'Lol.travel',
#   'Price 2': 318.0},
#  'Hotel Cafe Royal': {'Vendor 1': 'Booking.com',
#   'Price 1': 1133.0,
#   'Vendor 2': 'Expedia.it',
#   'Price 2': 1135.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 1135.0},
#  'Royal Lancaster London': {'Vendor 1': 'Booking.com',
#   'Price 1': 381.0,
#   'Vendor 2': 'Destinia.com',
#   'Price 2': 448.0},
#  'One Aldwych': {'Vendor 1': 'Booking.com',
#   'Price 1': 1030.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 838.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 1032.0},
#  'The Resident Victoria': {'Vendor 2': 'Agoda.com',
#   'Price 2': 220.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 220.0,
#   'Vendor 4': 'Lol.travel',
#   'Price 4': 220.0},
#  'Bankside Hotel': {'Vendor 1': 'Autograph',
#   'Price 1': 370.0,
#   'Vendor 2': 'Booking.com',
#   'Price 2': 370.0,
#   'Vendor 3': 'Etrip',
#   'Price 3': 329.0},
#  "Brown's Hotel": {'Vendor 1': 'Booking.com',
#   'Price 1': 1061.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 986.0,
#   'Vendor 3': 'FindHotel',
#   'Price 3': 868.0},
#  'The Chesterfield Mayfair': {'Vendor 1': 'Booking.com',
#   'Price 1': 594.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 568.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 595.0},
#  'Holmes Hotel London': {'Vendor 1': 'Booking.com',
#   'Price 1': 326.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 326.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 337.0},
#  'The Montcalm Royal London House': {'Vendor 1': 'Booking.com',
#   'Price 1': 251.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 264.0,
#   'Vendor 3': 'Destinia.com',
#   'Price 3': 262.0},
#  'The Connaught': {'Vendor 1': 'Booking.com',
#   'Price 1': 1055.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 1018.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 1056.0},
#  'The Resident Soho': {'Vendor 1': 'Booking.com',
#   'Price 1': 364.0,
#   'Vendor 2': 'FindHotel',
#   'Price 2': 310.0,
#   'Vendor 3': 'Agoda.com',
#   'Price 3': 332.0},
#  'The Kensington': {'Vendor 1': 'Booking.com',
#   'Price 1': 541.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 472.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 535.0},
#  'Wilde Aparthotels by Staycity - Aldgate Tower Bridge': {'Vendor 2': 'Booking.com',
#   'Price 2': 223.0,
#   'Vendor 3': 'Expedia.it',
#   'Price 3': 204.0,
#   'Vendor 4': 'Destinia.com',
#   'Price 4': 224.0},
#  'The Bloomsbury': {'Vendor 1': 'Booking.com',
#   'Price 1': 427.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 424.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 428.0},
#  'The Montcalm London Marble Arch': {'Vendor 1': 'Booking.com',
#   'Price 1': 291.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 240.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 262.0},
#  'Vintry & Mercer': {'Vendor 1': 'Booking.com',
#   'Price 1': 276.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 276.0,
#   'Vendor 3': 'Official Site',
#   'Price 3': 355.0},
#  'The Beaumont': {'Vendor 1': 'Booking.com',
#   'Price 1': 856.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 857.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 857.0},
#  "Batty Langley's": {'Vendor 1': 'Booking.com',
#   'Price 1': 301.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 302.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 302.0},
#  'Taj  Buckingham Gates Suites and Residences': {'Vendor 1': 'Booking.com',
#   'Price 1': 654.0,
#   'Vendor 2': 'Agoda.com',
#   'Price 2': 560.0,
#   'Vendor 3': 'Lol.travel',
#   'Price 3': 655.0},
#  'The Resident Kensington': {'Vendor 1': 'Booking.com',
#   'Price 1': 241.0,
#   'Vendor 2': 'Expedia.it',
#   'Price 2': 241.0,
#   'Vendor 3': 'eDreams',
#   'Price 3': 241.0}}

# %%
pd.DataFrame.from_dict(hotel_values)
# Out:
#          The Resident Covent Garden       Hotel  Shangri-La The Shard, London  \
# Vendor 1                Booking.com  Booking.com                  Booking.com
# Price 1                       499.0        564.0                        927.0
# Vendor 2                  Agoda.com    Agoda.com                   Expedia.it
# Price 2                       500.0        564.0                        929.0
# Vendor 3                 Lol.travel   Lol.travel                   Lol.travel
# Price 3                       500.0        565.0                        926.0
# Vendor 4                        NaN          NaN                          NaN
# Price 4                         NaN          NaN                          NaN
#
#          The Milestone Hotel and Residences Pan Pacific London   Claridge's  \
# Vendor 1                                NaN        Booking.com  Booking.com
# Price 1                                 NaN              438.0       1127.0
# Vendor 2                          Agoda.com          Agoda.com   Expedia.it
# Price 2                               529.0              438.0       1129.0
# Vendor 3                         Expedia.it                NaN   Lol.travel
# Price 3                               529.0                NaN       1129.0
# Vendor 4                                NaN                NaN          NaN
# Price 4                                 NaN                NaN          NaN
#
#          The Egerton House Hotel     The Hari The Montague on The Gardens  \
# Vendor 1             Booking.com  Booking.com                 Booking.com
# Price 1                    503.0        538.0                       317.0
# Vendor 2               Agoda.com    Agoda.com                  Lol.travel
# Price 2                    434.0        526.0                       318.0
# Vendor 3              Expedia.it      eDreams                         NaN
# Price 3                    504.0        538.0                         NaN
# Vendor 4                     NaN          NaN                         NaN
# Price 4                      NaN          NaN                         NaN
#
#          Hotel Cafe Royal  ... The Resident Soho The Kensington  \
# Vendor 1      Booking.com  ...       Booking.com    Booking.com
# Price 1            1133.0  ...             364.0          541.0
# Vendor 2       Expedia.it  ...         FindHotel      Agoda.com
# Price 2            1135.0  ...             310.0          472.0
# Vendor 3       Lol.travel  ...         Agoda.com     Lol.travel
# Price 3            1135.0  ...             332.0          535.0
# Vendor 4              NaN  ...               NaN            NaN
# Price 4               NaN  ...               NaN            NaN
#
#          Wilde Aparthotels by Staycity - Aldgate Tower Bridge The Bloomsbury  \
# Vendor 1                                                NaN      Booking.com
# Price 1                                                 NaN            427.0
# Vendor 2                                        Booking.com        Agoda.com
# Price 2                                               223.0            424.0
# Vendor 3                                         Expedia.it       Lol.travel
# Price 3                                               204.0            428.0
# Vendor 4                                       Destinia.com              NaN
# Price 4                                               224.0              NaN
#
#          The Montcalm London Marble Arch Vintry & Mercer The Beaumont  \
# Vendor 1                     Booking.com     Booking.com  Booking.com
# Price 1                            291.0           276.0        856.0
# Vendor 2                       Agoda.com       Agoda.com    Agoda.com
# Price 2                            240.0           276.0        857.0
# Vendor 3                      Lol.travel   Official Site   Lol.travel
# Price 3                            262.0           355.0        857.0
# Vendor 4                             NaN             NaN          NaN
# Price 4                              NaN             NaN          NaN
#
#          Batty Langley's Taj  Buckingham Gates Suites and Residences  \
# Vendor 1     Booking.com                                 Booking.com
# Price 1            301.0                                       654.0
# Vendor 2       Agoda.com                                   Agoda.com
# Price 2            302.0                                       560.0
# Vendor 3      Lol.travel                                  Lol.travel
# Price 3            302.0                                       655.0
# Vendor 4             NaN                                         NaN
# Price 4              NaN                                         NaN
#
#          The Resident Kensington
# Vendor 1             Booking.com
# Price 1                    241.0
# Vendor 2              Expedia.it
# Price 2                    241.0
# Vendor 3                 eDreams
# Price 3                    241.0
# Vendor 4                     NaN
# Price 4                      NaN
#
# [8 rows x 29 columns]
