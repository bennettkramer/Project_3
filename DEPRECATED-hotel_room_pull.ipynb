# %%
import pandas as pd
import json
import requests
import dotenv

# %%
url = "https://api.makcorps.com/auth"
header = {'Content-Type':'application/json'}
obj = {"username":"ryanderson94","password":"Mother_fucker1"}

# %%
request = requests.post(url=url, json = obj, headers=header)

# %%
response = json.loads(request.text)
access_token = response['access_token']
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE2NjA2OTE5ODUsImlhdCI6MTY2MDY5MDE4NSwibmJmIjoxNjYwNjkwMTg1LCJpZGVudGl0eSI6MTQ5MX0.KWJQXeTZqclwFLXNm2wU6Ul9fcvq5Aj5ifJhtUN9nPA'

# %%
authorization_key = 'JWT ' + access_token

# %%
booking_header = {}

# %%
booking_header['Authorization'] = authorization_key
booking_header
# Out:
# {'Authorization': 'JWT eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE2NjA2OTE5ODUsImlhdCI6MTY2MDY5MDE4NSwibmJmIjoxNjYwNjkwMTg1LCJpZGVudGl0eSI6MTQ5MX0.KWJQXeTZqclwFLXNm2wU6Ul9fcvq5Aj5ifJhtUN9nPA'}

# %%
booking_url = "https://api.makcorps.com/free/"
city = 'London'
pagination = '0'
currency = 'USD'
rooms = '1'
guests = '3'
checkin = '2021-08-21'
checkout = '2021-08-24'
concatenated_url = booking_url + city

# %%
concatenated_url
# Out:
# 'https://api.makcorps.com/free/London'

# %%
booking_request = requests.get(url = concatenated_url, headers=booking_header)

# %%
print(booking_request.text)
# Out:
# {
#     "Comparison": [
#         [
#             {
#                 "hotelName": "The Resident Covent Garden"
#             },
#             [
#                 {
#                     "price1": "299",
#                     "tax1": "60",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "300",
#                     "tax2": "60",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "298",
#                     "tax3": "60",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "358",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Hotel "
#             },
#             [
#                 {
#                     "price1": "502",
#                     "tax1": "100",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "504",
#                     "tax2": "101",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "501",
#                     "tax3": "100",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "601",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Shangri-La The Shard, London"
#             },
#             [
#                 {
#                     "price1": "906",
#                     "tax1": "181",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "853",
#                     "tax2": "171",
#                     "vendor2": "Trip.com"
#                 },
#                 {
#                     "price3": "908",
#                     "tax3": "182",
#                     "vendor3": "Destinia.com"
#                 },
#                 {
#                     "price4": "1153",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Milestone Hotel and Residences"
#             },
#             [
#                 {
#                     "price1": "488",
#                     "tax1": "98",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "489",
#                     "tax2": "98",
#                     "vendor2": "The Milestone"
#                 },
#                 {
#                     "price3": "490",
#                     "tax3": "98",
#                     "vendor3": "Agoda.com"
#                 },
#                 {
#                     "price4": "487",
#                     "tax4": "97",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Pan Pacific London"
#             },
#             [
#                 {
#                     "price1": "364",
#                     "tax1": "73",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "364",
#                     "tax2": "73",
#                     "vendor2": "Official Site"
#                 },
#                 {
#                     "price3": "365",
#                     "tax3": "73",
#                     "vendor3": "Agoda.com"
#                 },
#                 {
#                     "price4": "363",
#                     "tax4": "73",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Claridge's"
#             },
#             [
#                 {
#                     "price1": "936",
#                     "tax1": "187",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "934",
#                     "tax2": "187",
#                     "vendor2": "Trip.com"
#                 },
#                 {
#                     "price3": "938",
#                     "tax3": "188",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": "934",
#                     "tax4": "187",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Egerton House Hotel"
#             },
#             [
#                 {
#                     "price1": "418",
#                     "tax1": "84",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "357",
#                     "tax2": "71",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "417",
#                     "tax3": "83",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "500",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Hari"
#             },
#             [
#                 {
#                     "price1": "435",
#                     "tax1": "87",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "423",
#                     "tax2": "85",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "457",
#                     "tax3": "91",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "449",
#                     "tax4": "90",
#                     "vendor4": "Trip.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montague on The Gardens"
#             },
#             [
#                 {
#                     "price1": "293",
#                     "tax1": "59",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "293",
#                     "tax2": "59",
#                     "vendor2": "Montague Hotel"
#                 },
#                 {
#                     "price3": "256",
#                     "tax3": "51",
#                     "vendor3": "Agoda.com"
#                 },
#                 {
#                     "price4": "351",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Hotel Cafe Royal"
#             },
#             [
#                 {
#                     "price1": "941",
#                     "tax1": "188",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "939",
#                     "tax2": "188",
#                     "vendor2": "Trip.com"
#                 },
#                 {
#                     "price3": "939",
#                     "tax3": "188",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "943",
#                     "tax4": "189",
#                     "vendor4": "Expedia.it"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Royal Lancaster London"
#             },
#             [
#                 {
#                     "price1": "265",
#                     "tax1": "53",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "381",
#                     "tax2": "76",
#                     "vendor2": "Hotels.com"
#                 },
#                 {
#                     "price3": "412",
#                     "tax3": "82",
#                     "vendor3": "Preferred Hotels"
#                 },
#                 {
#                     "price4": "316",
#                     "tax4": "63",
#                     "vendor4": "Trip.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "One Aldwych"
#             },
#             [
#                 {
#                     "price1": "805",
#                     "tax1": "161",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "652",
#                     "tax2": "130",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "804",
#                     "tax3": "161",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "964",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Victoria"
#             },
#             [
#                 {
#                     "price1": "166",
#                     "tax1": "33",
#                     "vendor1": "Agoda.com"
#                 },
#                 {
#                     "price2": "165",
#                     "tax2": "33",
#                     "vendor2": "Hotels.com"
#                 },
#                 {
#                     "price3": "165",
#                     "tax3": "33",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "165",
#                     "tax4": "33",
#                     "vendor4": "Expedia.it"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Bankside Hotel"
#             },
#             [
#                 {
#                     "price1": "307",
#                     "tax1": "61",
#                     "vendor1": "Autograph"
#                 },
#                 {
#                     "price2": "307",
#                     "tax2": "61",
#                     "vendor2": "Booking.com"
#                 },
#                 {
#                     "price3": "308",
#                     "tax3": "62",
#                     "vendor3": "Agoda.com"
#                 },
#                 {
#                     "price4": "327",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Brown's Hotel"
#             },
#             [
#                 {
#                     "price1": "881",
#                     "tax1": "176",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "730",
#                     "tax2": "146",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "719",
#                     "tax3": "144",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "946",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Chesterfield Mayfair"
#             },
#             [
#                 {
#                     "price1": "493",
#                     "tax1": "99",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "495",
#                     "tax2": "99",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "485",
#                     "tax3": "97",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "492",
#                     "tax4": "98",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Holmes Hotel London"
#             },
#             [
#                 {
#                     "price1": "298",
#                     "tax1": "60",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "302",
#                     "tax2": "60",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "300",
#                     "tax3": "60",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "375",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montcalm Royal London House"
#             },
#             [
#                 {
#                     "price1": "203",
#                     "tax1": "43",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "216",
#                     "tax2": "43",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "204",
#                     "tax3": "41",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "215",
#                     "tax4": "43",
#                     "vendor4": "Trip.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Connaught"
#             },
#             [
#                 {
#                     "price1": "876",
#                     "tax1": "175",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "879",
#                     "tax2": "176",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "874",
#                     "tax3": "175",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "874",
#                     "tax4": "175",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Soho"
#             },
#             [
#                 {
#                     "price1": "304",
#                     "tax1": "61",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "303",
#                     "tax2": "61",
#                     "vendor2": "Hotels.com"
#                 },
#                 {
#                     "price3": "303",
#                     "tax3": "61",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "305",
#                     "tax4": "61",
#                     "vendor4": "Expedia.it"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Kensington"
#             },
#             [
#                 {
#                     "price1": "412",
#                     "tax1": "82",
#                     "vendor1": "Trip.com"
#                 },
#                 {
#                     "price2": "452",
#                     "tax2": "90",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "448",
#                     "tax3": "90",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "536",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Wilde Aparthotels by Staycity - Aldgate Tower Bridge"
#             },
#             [
#                 {
#                     "price1": "187",
#                     "tax1": "37",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "187",
#                     "tax2": "37",
#                     "vendor2": "Hotels.com"
#                 },
#                 {
#                     "price3": "163",
#                     "tax3": "33",
#                     "vendor3": "Destinia.com"
#                 },
#                 {
#                     "price4": "172",
#                     "tax4": "34",
#                     "vendor4": "Trip.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Bloomsbury"
#             },
#             [
#                 {
#                     "price1": "355",
#                     "tax1": "71",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "331",
#                     "tax2": "66",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "356",
#                     "tax3": "71",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "425",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Montcalm London Marble Arch"
#             },
#             [
#                 {
#                     "price1": "239",
#                     "tax1": "51",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "199",
#                     "tax2": "40",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "234",
#                     "tax3": "47",
#                     "vendor3": "Hotels.com"
#                 },
#                 {
#                     "price4": "255",
#                     "tax4": "51",
#                     "vendor4": "Expedia.it"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Vintry & Mercer"
#             },
#             [
#                 {
#                     "price1": "243",
#                     "tax1": "49",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "244",
#                     "tax2": "49",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "348",
#                     "tax3": "70",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "313",
#                     "tax4": "63",
#                     "vendor4": "Official Site"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Beaumont"
#             },
#             [
#                 {
#                     "price1": "711",
#                     "tax1": "142",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "714",
#                     "tax2": "143",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "697",
#                     "tax3": "140",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "709",
#                     "tax4": "142",
#                     "vendor4": "Hotels.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Batty Langley's"
#             },
#             [
#                 {
#                     "price1": "251",
#                     "tax1": "50",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "252",
#                     "tax2": "50",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "246",
#                     "tax3": "49",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": null,
#                     "tax4": null,
#                     "vendor4": null
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "Taj  Buckingham Gates Suites and Residences"
#             },
#             [
#                 {
#                     "price1": "544",
#                     "tax1": "109",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "449",
#                     "tax2": "90",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "483",
#                     "tax3": "97",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "651",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Resident Kensington"
#             },
#             [
#                 {
#                     "price1": "201",
#                     "tax1": "40",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "201",
#                     "tax2": "40",
#                     "vendor2": "Hotels.com"
#                 },
#                 {
#                     "price3": "202",
#                     "tax3": "40",
#                     "vendor3": "Expedia.it"
#                 },
#                 {
#                     "price4": "201",
#                     "tax4": "40",
#                     "vendor4": "Trip.com"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         [
#             {
#                 "hotelName": "The Stafford London"
#             },
#             [
#                 {
#                     "price1": "647",
#                     "tax1": "129",
#                     "vendor1": "Booking.com"
#                 },
#                 {
#                     "price2": "649",
#                     "tax2": "130",
#                     "vendor2": "Agoda.com"
#                 },
#                 {
#                     "price3": "453",
#                     "tax3": "91",
#                     "vendor3": "Trip.com"
#                 },
#                 {
#                     "price4": "775",
#                     "tax4": "0",
#                     "vendor4": "Lol.travel"
#                 },
#                 {
#                     "price5": null,
#                     "tax5": null,
#                     "vendor5": null
#                 }
#             ]
#         ],
#         {
#             "totalHotelsCount": "4,236",
#             "currentPageHotelsCount": 30,
#             "totalpageCount": "142"
#         }
#     ]
# }

# %%
data = booking_request.json()
data = data['Comparison']
last_hotel = data[-2][0]['hotelName']

# %%
hotel_list = []
hotel_prices = {}
price_list = []
hotel_values = {}
i = 0
n = 0
k = 1

# %%
while data[i][0]['hotelName'] != last_hotel:
    hotel_list.append(data[i][0]['hotelName'])
    
    while k < 6:
        if type(data[i][1][n][f'price{k}']) == str:
            hotel_prices[f'Vendor {k}'] = data[i][1][n][f'vendor{k}']
            hotel_prices[f'Price {k}'] = float(data[i][1][n][f'price{k}']) + float(data[i][1][n][f'tax{k}'])
        k += 1
        n += 1
    
    hotel_values[data[i][0]['hotelName']] = hotel_prices
    hotel_prices = {}
    i += 1
    k = 1
    n = 0

# %%
while data[i][0]['hotelName'] != last_hotel:
    hotel_list.append(data[i][0]['hotelName'])
    
    while k < 6:
        if type(data[i][1][n][f'price{k}']) == str:
            price_list.append(float(data[i][1][n][f'price{k}']) + float(data[i][1][n][f'tax{k}']))
        k += 1
        n += 1
    
    hotel_values[data[i][0]['hotelName']] = min(price_list)
    hotel_prices = {}
    price_list = []
    i += 1
    k = 1
    n = 0

# %%
hotel_values
# Out:
# {'The Resident Covent Garden': 358.0,
#  'Hotel ': 601.0,
#  'Shangri-La The Shard, London': 1024.0,
#  'The Milestone Hotel and Residences': 584.0,
#  'Pan Pacific London': 436.0,
#  "Claridge's": 1121.0,
#  'The Egerton House Hotel': 428.0,
#  'The Hari': 508.0,
#  'The Montague on The Gardens': 307.0,
#  'Hotel Cafe Royal': 1127.0,
#  'Royal Lancaster London': 318.0,
#  'One Aldwych': 782.0,
#  'The Resident Victoria': 198.0,
#  'Bankside Hotel': 327.0,
#  "Brown's Hotel": 863.0,
#  'The Chesterfield Mayfair': 582.0,
#  'Holmes Hotel London': 358.0,
#  'The Montcalm Royal London House': 245.0,
#  'The Connaught': 1049.0,
#  'The Resident Soho': 364.0,
#  'The Kensington': 494.0,
#  'Wilde Aparthotels by Staycity - Aldgate Tower Bridge': 196.0,
#  'The Bloomsbury': 397.0,
#  'The Montcalm London Marble Arch': 239.0,
#  'Vintry & Mercer': 292.0,
#  'The Beaumont': 837.0,
#  "Batty Langley's": 295.0,
#  'Taj  Buckingham Gates Suites and Residences': 539.0,
#  'The Resident Kensington': 241.0}

# %%
hotel_list_df = pd.DataFrame(hotel_list, columns=['Hotel'])
hotel_price_df = pd.DataFrame(price_list, columns=['Price'])
display(hotel_list_df)
display(hotel_price_df)
# Out:
# Empty DataFrame
# Columns: [Hotel]
# Index: []
# Empty DataFrame
# Columns: [Price]
# Index: []

# %%
concat_frame = [hotel_list, price_list]
hotel_values_df = pd.concat(concat_frame, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gy/jpg9vtpx0mx_51mt99fhc2pc0000gn/T/ipykernel_4778/3096971278.py in <module>
#       1 concat_frame = [hotel_list, price_list]
# ----> 2 hotel_values_df = pd.concat(concat_frame, axis=1)
#
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     382                     "only Series and DataFrame objs are valid"
#     383                 )
# --> 384                 raise TypeError(msg)
#     385
#     386             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'list'>'; only Series and DataFrame objs are valid
